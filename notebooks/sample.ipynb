# %%
import pandas as pd
df = pd.read_csv('../data/risk_scored_portfolio.csv')
print(df.columns.tolist())
# Out:
# ['loan_id', 'customer_id', 'product_type', 'loan_amount', 'tenure_months', 'interest_rate', 'emi_amount', 'risk_grade', 'origination_date', 'processing_fee', 'loan_purpose', 'disbursement_date', 'co_borrower_flag', 'default_flag', 'days_to_default', 'default_month', 'total_amount_paid', 'total_amount_pending', 'recovery_amount', 'closure_date', 'write_off_flag', 'age', 'gender', 'city_tier', 'city_name', 'employment_type', 'monthly_income', 'credit_score', 'existing_loans', 'years_employed', 'education_level', 'acquisition_channel', 'onboarding_date', 'avg_dpd_first_3_months', 'late_payment_count_first_3_months', 'avg_stress_score', 'emi_to_income', 'risk_score', 'risk_probability', 'risk_tier', 'scorecard_points', 'decision']

# %%
df = pd.read_csv('../data/customer_profile.csv')
print(df.columns.tolist())
# Out:
# ['customer_id', 'age', 'gender', 'city_tier', 'city_name', 'employment_type', 'monthly_income', 'credit_score', 'existing_loans', 'years_employed', 'education_level', 'acquisition_channel', 'onboarding_date']

# %%
df = pd.read_csv('../data/loan_outcome.csv')
print(df.columns.tolist())
# Out:
# ['loan_id', 'customer_id', 'product_type', 'default_flag', 'days_to_default', 'default_month', 'total_amount_paid', 'total_amount_pending', 'recovery_amount', 'closure_date', 'write_off_flag']

# %%
df = pd.read_csv('../data/loan_details.csv')
print(df.columns.tolist())
# Out:
# ['loan_id', 'customer_id', 'product_type', 'loan_amount', 'tenure_months', 'interest_rate', 'emi_amount', 'risk_grade', 'origination_date', 'processing_fee', 'loan_purpose', 'disbursement_date', 'co_borrower_flag']

# %%
df = pd.read_csv('../data/repayment_behavior.csv')
print(df.columns.tolist())
# Out:
# ['repayment_id', 'loan_id', 'customer_id', 'month_number', 'due_date', 'payment_date', 'amount_due', 'amount_paid', 'dpd', 'payment_status', 'bounce_flag']
